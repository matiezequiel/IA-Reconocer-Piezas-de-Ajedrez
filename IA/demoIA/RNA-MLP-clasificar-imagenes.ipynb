# %% [markdown]
# # Demo RNA Multi-Perceptrón Backpropagation usando Keras para procesar imágenes e identificar la clase que corresponde

# %% [markdown]
# 1) Cargar librerías:

# %%
#@title Librerías a usar
from tensorflow import keras
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.layers import BatchNormalization, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
from sklearn.model_selection import train_test_split

from keras.utils import np_utils

import tensorflow as tf
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
import os

from PIL import Image

from  sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

print("Librerías cargadas")
# Out:
# Librerías cargadas

# %% [markdown]
# 2) Definir los parámetros:

# %%
## selección de los parámetros 

# 
#@markdown ### Parámetros de imágenes:
imagen_largo_ancho =  256#@param {type:"integer"}
imagen_color = True #@param {type:"boolean"}
imagen_usar_generadas_data_augmentation = True # param {type:"boolean"}

#@markdown ### Parámetros de la red:
rna_cant_neuronas_capas_ocultas = '400, 200, 100, 6' #@param {type:"string"}
rna_tipo_capa_salida = 'softmax-MultiClase' #@param ["lineal-Numero", "softmax-MultiClase"]
rna_cant_epocas_entrenamiento =  150#@param {type:"integer"}


## aplicación de los parámetros elegidos

# tamaño de las imágenes
if imagen_largo_ancho<=10:
  imagen_largo_ancho = 10
IMAGE_SHAPE = (imagen_largo_ancho, imagen_largo_ancho, (3 if imagen_color else 1))

# indica si se usan las imágenes generadas por data augmentation
usarDA = imagen_usar_generadas_data_augmentation

# define tamaño de datos de entrada 
num_inputs = IMAGE_SHAPE[0] * IMAGE_SHAPE[1] * IMAGE_SHAPE[2]

# cantidad de neuronas ocultas 
##hidden_layers = [ num_inputs//5, num_inputs//20, num_inputs//100 ]
hidden_layers = []
for val in rna_cant_neuronas_capas_ocultas.split(', '):
  if val == "D":
    hidden_layers.append( "DropOut" )  
  elif val == "BN":
    hidden_layers.append( "BatchNormalization" )  
  elif val.isnumeric():
    hidden_layers.append( val )
  else:
    print("Capa ", val, "descartada!")

# define si el tipo de capa de salida es softmax( True )  o lineal ( False )
# esto implica también cambiar cómo se codifican los valores de las clases a usar
tipo_output_softMax = (rna_tipo_capa_salida[:7] == 'softmax')

# cantidad de épocas del entrenamiento
cantEpocas = (100 if rna_cant_epocas_entrenamiento<1 else rna_cant_epocas_entrenamiento)

print ("Tamaño Imagen: ", IMAGE_SHAPE)
print("Configuración de RNA MLP Backpropagation definida: \n[", num_inputs, hidden_layers, ("Softmax" if tipo_output_softMax else "Dense[1] "))
# Out:
# Tamaño Imagen:  (256, 256, 3)
# Configuración de RNA MLP Backpropagation definida:
# [ 196608 ['400', '200', '100', '6'] Softmax

# %% [markdown]
# 3) Montar el Drive:

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)

# directorio local en Google Drive
path = 'gdrive/My Drive/IA/demoIA/imagenesAjedrez4' #@param {type:"string"}
path_entrenamiento = '/train'  #@param {type:"string"}
path_prueba = '/test'  #@param {type:"string"}

imagPath_train = path + path_entrenamiento
imagPath_test = path + path_prueba
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# 4) Cargar imágenes para entrenar el modelo:

# %%
#@title Cargar imágenes
# define función para cargar las imágenes
def cargarImagenes(imagPath):
  classes_ori = [] 
  images_ori = []
  esDA_ori = []

  all_dirs = os.listdir( imagPath )
  for each_dir in all_dirs:

      auxiPath = imagPath + '/' + each_dir 
      imagFN  = os.listdir( auxiPath )
      for each_imagFN in imagFN:

            esImagDA = (each_imagFN[:2] == 'da')
            
            if usarDA or (not esImagDA): 
                
                # abre la imagen
                imag = Image.open(auxiPath + "/" + each_imagFN)
                
                # ajusta el tamaño
                if IMAGE_SHAPE[2]==1:              
                  tipoImage = 'L'
                else:                
                  tipoImage = 'RGB'
                imag = imag.convert(tipoImage)
                imag = imag.resize((IMAGE_SHAPE[0], IMAGE_SHAPE[1]), Image.ANTIALIAS)          
                
                # transforma a un vector de nros
                arImag = np.array(imag)
                
                # agrega a los vectores
                classes_ori.append( each_dir )
                images_ori.append( arImag )
                esDA_ori.append( esImagDA )

  return classes_ori, images_ori, esDA_ori, tipoImage

# carga las imagenes de entrenamiento
classes_train, images_train, esDAimag_train, tipoImage_train = cargarImagenes(imagPath_train)
print("> Para Entrenamiento: ")
print("- Clases cargadas: ", len(classes_train))
print("- Imágenes cargadas: ", len(classes_train))

if len(classes_train)>0:
  print("- Ejemplo ", classes_train[0], " ", images_train[0].shape, ": ")
  display( Image.fromarray(images_train[0], tipoImage_train) )

# carga las imagenes de prueba
classes_test, images_test, esDAimag_test, tipoImage_test = cargarImagenes(imagPath_test)
print("\n\n> Para Prueba: ")
print("- Clases cargadas: ", len(classes_test))
print("- Imágenes cargadas: ", len(images_test))

if len(classes_test)>0:
  print("- Ejemplo ", classes_test[0], " ", images_test[0].shape, ": ")
  display( Image.fromarray(images_test[0], tipoImage_test) )
# Out:
# > Para Entrenamiento:
# - Clases cargadas:  24
# - Imágenes cargadas:  24
# - Ejemplo  peon   (256, 256, 3) :
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F673012E350>
# > Para Prueba:
# - Clases cargadas:  18
# - Imágenes cargadas:  18
# - Ejemplo  rey   (256, 256, 3) :
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F67C6A0AD10>

# %%
#@title Preparar imágenes
# define función auxiliar para mostrar imágenes preparadas
def plot_image(imag):
  if IMAGE_SHAPE[2]==1:
    plt.imshow((imag*255).reshape(IMAGE_SHAPE[0], IMAGE_SHAPE[1]).astype(np.uint8))
    plt.gray()
  else:
    plt.imshow((imag*255).reshape(IMAGE_SHAPE).astype(np.uint8))
  plt.axis("off")  

# define función auxiliar para preparar la lista de imágenes a procesar
def prepare_imageList(imagList):    
  auxiAr = np.array(imagList).astype('float32') / 255.
  auxiAr = auxiAr.reshape((len(auxiAr), num_inputs))  
  return np.array(auxiAr)

# define función auxiliar para preparar lista de clases 
def prepare_clasesList(classesList, dictMapeo=None):
  if dictMapeo==None:
    # genera diccionario de mapeo
    auxDict = list(set(classesList))
    dictMapeo = dict( zip( auxDict, range(len(auxDict)) ) )
  # realiza el mapeo
  y = []
  for cl in classesList:
      y.append( dictMapeo[cl] )
  # convierte valores numéricos a columnas de vakores binarios (i.e. one hot encoded)
  dummy_y = np_utils.to_categorical(y)
  # devuelve
  return np.array(y), np.array(dummy_y), dictMapeo

# define vector auxiliar de datos de entrada para usar en el entrenamiento y prueba
x_train = prepare_imageList(images_train)
x_test = prepare_imageList(images_test)

# define vector auxiliar de datos de salida para usar en el entrenamiento y prueba
# también usa esta información para determinar la cantida de neuronas de salida
y_train, y_trainEnc, dictMapeo = prepare_clasesList(classes_train)
y_test, y_testEnc,_ = prepare_clasesList(classes_test, dictMapeo)

# genera diccionario auxiliar para poder convertir de ID de clase a nombre de clase
clases_map = [ x for x,y in dictMapeo.items() ]

print("> Para Entrenamiento: ")
print(" - x_train (cant ejemplos, datos entrada): ", x_train.shape)
if tipo_output_softMax:
  print(" - y_trainEnc (cant): ", len(y_trainEnc))
else:
  print(" - y_train (cant): ", len(y_train))
print("\n\n> Para Prueba: ")
print(" - x_test (cant ejemplos, datos entrada): ", x_test.shape)
if tipo_output_softMax:
  print(" - y_testEnc (cant): ", len(y_testEnc))
else:
  print(" - y_test (cant): ", len(y_test))
print("\n\n> Para Ambos: ")
print(" - dictMapeo: ", dictMapeo)
print(" - clases_map: ", clases_map)
if len(y_train)>0:
  print("\n - Imagen reconstruida de ", clases_map[y_train[0]],  "(", y_train[0], " / ", y_trainEnc[0], ")")
  plot_image(x_train[0])
# Out:
# > Para Entrenamiento:
#  - x_train (cant ejemplos, datos entrada):  (24, 196608)
#  - y_trainEnc (cant):  24
#
#
# > Para Prueba:
#  - x_test (cant ejemplos, datos entrada):  (18, 196608)
#  - y_testEnc (cant):  18
#
#
# > Para Ambos:
#  - dictMapeo:  {'reina': 0, 'peon': 1, 'caballo': 2, 'rey': 3, 'torre': 4, 'alfil': 5}
#  - clases_map:  ['reina', 'peon', 'caballo', 'rey', 'torre', 'alfil']
#
#  - Imagen reconstruida de  peon ( 1  /  [0. 1. 0. 0. 0. 0.] )

# %% [markdown]
# 5) Establecer el modelo para la RNA:

# %%
#@title Establecer modelo

opt_tipo = "Gradiente Decreciente" # param ["Gradiente Decreciente", "Adam", "Adadelta", "Adagrad", "Adamax", "Nadam", "FTRL"]
opt_learning_rate = 0.001 #@param {type: "number"}

# define la arquitectura de capas teniendo en cuenta la definición dada anteriomente
input_img_Lay = Input(shape=(num_inputs,), name='input_img') # capa de entrada
eachLay = input_img_Lay
auxName = 'hidd_'
auxId = 1 
for val_hid in hidden_layers:  

  if val_hid == "DropOut":
    eachLay = Dropout(0.2)(eachLay)
  elif val_hid == "BatchNormalization":
    auxlayerName = "bn"+str(auxId)
    auxId = auxId + 1
    eachLay = BatchNormalization(name=auxlayerName)(eachLay)
  elif val_hid.isnumeric():
    # agrega la capa oculta
    auxlayerName = auxName+str(auxId)
    auxId = auxId + 1
    eachLay = Dense(int(val_hid), name=auxlayerName)(eachLay) # capas ocultas

# agrega capa de salida
if tipo_output_softMax:
    # se genera una capa softmax
    output_img_Lay = Dense(units = len(dictMapeo), activation='softmax', name='output')(eachLay) # capa de salida
else:
    # se genera una capa lineal con una salida numérica
    output_img_Lay = Dense(1, activation=None, name='output')(eachLay) # capa de salida


if opt_tipo == "Gradiente Decreciente":
  opt = keras.optimizers.SGD(learning_rate=opt_learning_rate)
elif opt_tipo == "Adam":
  opt = keras.optimizers.Adam(learning_rate=opt_learning_rate)
elif opt_tipo == "Adadelta":
  opt = keras.optimizers.Adadelta(learning_rate=opt_learning_rate)
elif opt_tipo == "Adagrad":
  opt = keras.optimizers.Adagrad(learning_rate=opt_learning_rate)
elif opt_tipo == "Adamax":
  opt = keras.optimizers.Adamax(learning_rate=opt_learning_rate)
elif opt_tipo == "Nadam":
  opt = keras.optimizers.Nadam(learning_rate=opt_learning_rate)
elif opt_tipo == "FTRL":
  opt = keras.optimizers.Ftrl(learning_rate=opt_learning_rate)
else:
  opt = keras.optimizers.Adam()

# genera el modelo RNA MLP Backpropagation
model = Model(input_img_Lay, output_img_Lay, name='RNA')
if tipo_output_softMax:
    # utiliza un loss de multiple clases
    model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
else:
    # utiliza un loss de valor numérico
    model.compile(optimizer=opt, loss='mse', metrics=['accuracy'])

print("Modelo creado con ", len(model.layers), " capas:")
model.summary()
print("\n")
plot_model(model, show_layer_names=True, show_shapes=True)
# Out:
# Modelo creado con  6  capas:
# Model: "RNA"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_img (InputLayer)      [(None, 196608)]          0
#
#  hidd_1 (Dense)              (None, 400)               78643600
#
#  hidd_2 (Dense)              (None, 200)               80200
#
#  hidd_3 (Dense)              (None, 100)               20100
#
#  hidd_4 (Dense)              (None, 6)                 606
#
#  output (Dense)              (None, 6)                 42
#
# =================================================================
# Total params: 78,744,548
# Trainable params: 78,744,548
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 6) Entrenar el modelo de la RNA:

# %%
#@title Entrenar

activar_corte_por_estabilidad_error_val = False 

# separa al azar usando muestreo al azar del 10%
# para tomar algunos como datos de validación
x_t, x_v, y_t, y_v = train_test_split(x_train, 
                                       (y_trainEnc if tipo_output_softMax else y_train), 
                                       test_size=0.1)

print("\n> De los ", len(x_train), "ejemplos de entrenamiento: ")
print("            se usan ", len(x_t), "ejemplos para entrenar ")
print("            y ", len(x_v), "ejemplos para validar.")

print("\n\n>Comienza el Entrenamiento:")

if activar_corte_por_estabilidad_error_val:
  # se agrega un callBack para que corte 
  # si el error de validación no sigue bajando
  # y devuelva los mejores pesos obtenidos
  early_stopping_monitor = keras.callbacks.EarlyStopping(
      monitor='val_loss',
      min_delta=0.01,
      patience=20,
      verbose=0,
      mode='min',
      baseline=None,
      restore_best_weights=True
  )
  callbacksEntr = [early_stopping_monitor]
else:
  early_stopping_monitor = None
  callbacksEntr = []

# lleva a cabo el entrenamiento
history = model.fit(x_t, y_t,
          epochs = cantEpocas, 
          validation_data=(x_v, y_v,),
          callbacks=callbacksEntr ) 

print("\n>Entrenamiento Finalizado.")
# Out:
# > De los  24 ejemplos de entrenamiento:
#             se usan  21 ejemplos para entrenar
#             y  3 ejemplos para validar.
#
#
# >Comienza el Entrenamiento:
# Epoch 1/150
# 1/1 [==============================] - 0s 497ms/step - loss: 2.6075 - accuracy: 0.2381 - val_loss: 50.5724 - val_accuracy: 0.3333
# Epoch 2/150
# 1/1 [==============================] - 0s 47ms/step - loss: 125.0779 - accuracy: 0.1429 - val_loss: 87.9336 - val_accuracy: 0.3333
# Epoch 3/150
# 1/1 [==============================] - 0s 45ms/step - loss: 124.3338 - accuracy: 0.1429 - val_loss: 206.4858 - val_accuracy: 0.0000e+00
# Epoch 4/150
# 1/1 [==============================] - 0s 56ms/step - loss: 171.0463 - accuracy: 0.1905 - val_loss: 71.5775 - val_accuracy: 0.0000e+00
# Epoch 5/150
# 1/1 [==============================] - 0s 45ms/step - loss: 111.5844 - accuracy: 0.1905 - val_loss: 194.6968 - val_accuracy: 0.0000e+00
# Epoch 6/150
# 1/1 [==============================] - 0s 47ms/step - loss: 260.4587 - accuracy: 0.1905 - val_loss: 91.5833 - val_accuracy: 0.3333
# Epoch 7/150
# 1/1 [==============================] - 0s 46ms/step - loss: 138.7685 - accuracy: 0.1429 - val_loss: 118.8585 - val_accuracy: 0.0000e+00
# Epoch 8/150
# 1/1 [==============================] - 0s 54ms/step - loss: 106.3179 - accuracy: 0.1905 - val_loss: 190.3245 - val_accuracy: 0.0000e+00
# Epoch 9/150
# 1/1 [==============================] - 0s 44ms/step - loss: 237.6012 - accuracy: 0.1905 - val_loss: 0.7956 - val_accuracy: 0.6667
# Epoch 10/150
# 1/1 [==============================] - 0s 45ms/step - loss: 6.2977 - accuracy: 0.2381 - val_loss: 24.8809 - val_accuracy: 0.0000e+00
# Epoch 11/150
# 1/1 [==============================] - 0s 46ms/step - loss: 33.7865 - accuracy: 0.1905 - val_loss: 33.0190 - val_accuracy: 0.0000e+00
# Epoch 12/150
# 1/1 [==============================] - 0s 44ms/step - loss: 47.5479 - accuracy: 0.1905 - val_loss: 35.2255 - val_accuracy: 0.3333
# Epoch 13/150
# 1/1 [==============================] - 0s 52ms/step - loss: 63.7589 - accuracy: 0.1429 - val_loss: 15.6593 - val_accuracy: 0.3333
# Epoch 14/150
# 1/1 [==============================] - 0s 46ms/step - loss: 16.8855 - accuracy: 0.1905 - val_loss: 71.6345 - val_accuracy: 0.3333
# Epoch 15/150
# 1/1 [==============================] - 0s 44ms/step - loss: 70.5872 - accuracy: 0.1429 - val_loss: 30.6627 - val_accuracy: 0.0000e+00
# Epoch 16/150
# 1/1 [==============================] - 0s 45ms/step - loss: 27.8118 - accuracy: 0.1905 - val_loss: 22.6014 - val_accuracy: 0.0000e+00
# Epoch 17/150
# 1/1 [==============================] - 0s 45ms/step - loss: 23.9491 - accuracy: 0.1905 - val_loss: 5.2955 - val_accuracy: 0.3333
# Epoch 18/150
# 1/1 [==============================] - 0s 49ms/step - loss: 12.8577 - accuracy: 0.3810 - val_loss: 6.3748 - val_accuracy: 0.3333
# Epoch 19/150
# 1/1 [==============================] - 0s 46ms/step - loss: 14.1302 - accuracy: 0.1429 - val_loss: 14.0744 - val_accuracy: 0.0000e+00
# Epoch 20/150
# 1/1 [==============================] - 0s 48ms/step - loss: 16.9319 - accuracy: 0.2381 - val_loss: 12.6350 - val_accuracy: 0.0000e+00
# Epoch 21/150
# 1/1 [==============================] - 0s 45ms/step - loss: 15.3480 - accuracy: 0.1905 - val_loss: 3.6415 - val_accuracy: 0.6667
# Epoch 22/150
# 1/1 [==============================] - 0s 47ms/step - loss: 11.6282 - accuracy: 0.2381 - val_loss: 7.4425 - val_accuracy: 0.3333
# Epoch 23/150
# 1/1 [==============================] - 0s 46ms/step - loss: 8.7807 - accuracy: 0.2381 - val_loss: 10.8309 - val_accuracy: 0.0000e+00
# Epoch 24/150
# 1/1 [==============================] - 0s 46ms/step - loss: 6.4615 - accuracy: 0.4286 - val_loss: 9.5732 - val_accuracy: 0.0000e+00
# Epoch 25/150
# 1/1 [==============================] - 0s 44ms/step - loss: 8.6711 - accuracy: 0.2381 - val_loss: 7.2716 - val_accuracy: 0.0000e+00
# Epoch 26/150
# 1/1 [==============================] - 0s 58ms/step - loss: 8.2336 - accuracy: 0.3333 - val_loss: 3.0768 - val_accuracy: 0.3333
# Epoch 27/150
# 1/1 [==============================] - 0s 45ms/step - loss: 6.0237 - accuracy: 0.2381 - val_loss: 5.5970 - val_accuracy: 0.3333
# Epoch 28/150
# 1/1 [==============================] - 0s 48ms/step - loss: 7.8924 - accuracy: 0.1905 - val_loss: 13.0830 - val_accuracy: 0.3333
# Epoch 29/150
# 1/1 [==============================] - 0s 45ms/step - loss: 8.0920 - accuracy: 0.2857 - val_loss: 9.6070 - val_accuracy: 0.0000e+00
# Epoch 30/150
# 1/1 [==============================] - 0s 48ms/step - loss: 6.3540 - accuracy: 0.2857 - val_loss: 8.6259 - val_accuracy: 0.3333
# Epoch 31/150
# 1/1 [==============================] - 0s 46ms/step - loss: 7.2330 - accuracy: 0.2857 - val_loss: 5.7473 - val_accuracy: 0.3333
# Epoch 32/150
# 1/1 [==============================] - 0s 45ms/step - loss: 3.0161 - accuracy: 0.4762 - val_loss: 3.6530 - val_accuracy: 0.0000e+00
# Epoch 33/150
# 1/1 [==============================] - 0s 44ms/step - loss: 3.2597 - accuracy: 0.4286 - val_loss: 2.8764 - val_accuracy: 0.0000e+00
# Epoch 34/150
# 1/1 [==============================] - 0s 46ms/step - loss: 3.3130 - accuracy: 0.4286 - val_loss: 0.6974 - val_accuracy: 0.6667
# Epoch 35/150
# 1/1 [==============================] - 0s 46ms/step - loss: 3.9206 - accuracy: 0.2857 - val_loss: 4.2778 - val_accuracy: 0.3333
# Epoch 36/150
# 1/1 [==============================] - 0s 44ms/step - loss: 3.9248 - accuracy: 0.2857 - val_loss: 7.3417 - val_accuracy: 0.3333
# Epoch 37/150
# 1/1 [==============================] - 0s 45ms/step - loss: 4.0152 - accuracy: 0.2857 - val_loss: 8.4456 - val_accuracy: 0.0000e+00
# Epoch 38/150
# 1/1 [==============================] - 0s 46ms/step - loss: 5.4202 - accuracy: 0.3333 - val_loss: 6.8381 - val_accuracy: 0.0000e+00
# Epoch 39/150
# 1/1 [==============================] - 0s 43ms/step - loss: 5.2262 - accuracy: 0.4286 - val_loss: 0.9735 - val_accuracy: 0.3333
# Epoch 40/150
# 1/1 [==============================] - 0s 45ms/step - loss: 2.4294 - accuracy: 0.3333 - val_loss: 3.4048 - val_accuracy: 0.3333
# Epoch 41/150
# 1/1 [==============================] - 0s 46ms/step - loss: 2.1905 - accuracy: 0.6190 - val_loss: 4.8127 - val_accuracy: 0.3333
# Epoch 42/150
# 1/1 [==============================] - 0s 49ms/step - loss: 2.6709 - accuracy: 0.4286 - val_loss: 3.7813 - val_accuracy: 0.0000e+00
# Epoch 43/150
# 1/1 [==============================] - 0s 48ms/step - loss: 2.9739 - accuracy: 0.4762 - val_loss: 2.6252 - val_accuracy: 0.0000e+00
# Epoch 44/150
# 1/1 [==============================] - 0s 46ms/step - loss: 2.1606 - accuracy: 0.4762 - val_loss: 0.6961 - val_accuracy: 0.6667
# Epoch 45/150
# 1/1 [==============================] - 0s 45ms/step - loss: 1.7222 - accuracy: 0.5238 - val_loss: 2.0109 - val_accuracy: 0.3333
# Epoch 46/150
# 1/1 [==============================] - 0s 47ms/step - loss: 0.9428 - accuracy: 0.6190 - val_loss: 1.8595 - val_accuracy: 0.3333
# Epoch 47/150
# 1/1 [==============================] - 0s 50ms/step - loss: 1.2819 - accuracy: 0.6667 - val_loss: 1.6282 - val_accuracy: 0.3333
# Epoch 48/150
# 1/1 [==============================] - 0s 46ms/step - loss: 1.2431 - accuracy: 0.6190 - val_loss: 3.0637 - val_accuracy: 0.3333
# Epoch 49/150
# 1/1 [==============================] - 0s 48ms/step - loss: 1.6105 - accuracy: 0.5714 - val_loss: 2.7836 - val_accuracy: 0.0000e+00
# Epoch 50/150
# 1/1 [==============================] - 0s 45ms/step - loss: 1.6536 - accuracy: 0.5714 - val_loss: 2.1317 - val_accuracy: 0.3333
# Epoch 51/150
# 1/1 [==============================] - 0s 50ms/step - loss: 1.2593 - accuracy: 0.5238 - val_loss: 1.3524 - val_accuracy: 0.3333
# Epoch 52/150
# 1/1 [==============================] - 0s 46ms/step - loss: 1.5516 - accuracy: 0.6667 - val_loss: 1.6384 - val_accuracy: 0.3333
# Epoch 53/150
# 1/1 [==============================] - 0s 44ms/step - loss: 1.2853 - accuracy: 0.4762 - val_loss: 2.9000 - val_accuracy: 0.3333
# Epoch 54/150
# 1/1 [==============================] - 0s 47ms/step - loss: 1.5137 - accuracy: 0.6667 - val_loss: 2.4988 - val_accuracy: 0.0000e+00
# Epoch 55/150
# 1/1 [==============================] - 0s 44ms/step - loss: 0.9475 - accuracy: 0.5714 - val_loss: 1.3103 - val_accuracy: 0.6667
# Epoch 56/150
# 1/1 [==============================] - 0s 50ms/step - loss: 1.3857 - accuracy: 0.6190 - val_loss: 1.2341 - val_accuracy: 0.3333
# Epoch 57/150
# 1/1 [==============================] - 0s 45ms/step - loss: 1.0656 - accuracy: 0.6667 - val_loss: 2.1283 - val_accuracy: 0.3333
# Epoch 58/150
# 1/1 [==============================] - 0s 45ms/step - loss: 0.9768 - accuracy: 0.7619 - val_loss: 2.3202 - val_accuracy: 0.3333
# Epoch 59/150
# 1/1 [==============================] - 0s 47ms/step - loss: 0.9198 - accuracy: 0.7619 - val_loss: 1.5741 - val_accuracy: 0.6667
# Epoch 60/150
# 1/1 [==============================] - 0s 47ms/step - loss: 0.8343 - accuracy: 0.6667 - val_loss: 2.0748 - val_accuracy: 0.3333
# Epoch 61/150
# 1/1 [==============================] - 0s 47ms/step - loss: 1.1097 - accuracy: 0.7143 - val_loss: 1.4050 - val_accuracy: 0.3333
# Epoch 62/150
# 1/1 [==============================] - 0s 45ms/step - loss: 0.6775 - accuracy: 0.8095 - val_loss: 2.5161 - val_accuracy: 0.3333
# Epoch 63/150
# 1/1 [==============================] - 0s 47ms/step - loss: 0.8041 - accuracy: 0.7619 - val_loss: 1.7486 - val_accuracy: 0.3333
# Epoch 64/150
# 1/1 [==============================] - 0s 48ms/step - loss: 0.7809 - accuracy: 0.7143 - val_loss: 1.8831 - val_accuracy: 0.3333
# Epoch 65/150
# 1/1 [==============================] - 0s 46ms/step - loss: 0.9305 - accuracy: 0.8095 - val_loss: 1.4655 - val_accuracy: 0.6667
# Epoch 66/150
# 1/1 [==============================] - 0s 45ms/step - loss: 0.6142 - accuracy: 0.7619 - val_loss: 2.2320 - val_accuracy: 0.3333
# Epoch 67/150
# 1/1 [==============================] - 0s 52ms/step - loss: 0.6941 - accuracy: 0.7619 - val_loss: 1.7745 - val_accuracy: 0.3333
# Epoch 68/150
# 1/1 [==============================] - 0s 45ms/step - loss: 0.7267 - accuracy: 0.7143 - val_loss: 1.9191 - val_accuracy: 0.3333
# Epoch 69/150
# 1/1 [==============================] - 0s 44ms/step - loss: 0.7770 - accuracy: 0.8095 - val_loss: 1.7546 - val_accuracy: 0.3333
# Epoch 70/150
# 1/1 [==============================] - 0s 58ms/step - loss: 0.7151 - accuracy: 0.7619 - val_loss: 2.0328 - val_accuracy: 0.3333
# Epoch 71/150
# 1/1 [==============================] - 0s 45ms/step - loss: 0.7186 - accuracy: 0.7143 - val_loss: 1.9653 - val_accuracy: 0.3333
# Epoch 72/150
# 1/1 [==============================] - 0s 45ms/step - loss: 0.7969 - accuracy: 0.7143 - val_loss: 1.9415 - val_accuracy: 0.3333
# Epoch 73/150
# 1/1 [==============================] - 0s 46ms/step - loss: 0.7077 - accuracy: 0.7619 - val_loss: 1.8936 - val_accuracy: 0.3333
# Epoch 74/150
# 1/1 [==============================] - 0s 50ms/step - loss: 0.7563 - accuracy: 0.7143 - val_loss: 1.9350 - val_accuracy: 0.3333
# Epoch 75/150
# 1/1 [==============================] - 0s 47ms/step - loss: 0.6789 - accuracy: 0.7619 - val_loss: 1.9583 - val_accuracy: 0.3333
# Epoch 76/150
# 1/1 [==============================] - 0s 48ms/step - loss: 0.7193 - accuracy: 0.7619 - val_loss: 1.9406 - val_accuracy: 0.3333
# Epoch 77/150
# 1/1 [==============================] - 0s 49ms/step - loss: 0.6365 - accuracy: 0.7619 - val_loss: 1.8873 - val_accuracy: 0.3333
# Epoch 78/150
# 1/1 [==============================] - 0s 59ms/step - loss: 0.6640 - accuracy: 0.7619 - val_loss: 1.9332 - val_accuracy: 0.3333
# Epoch 79/150
# 1/1 [==============================] - 0s 46ms/step - loss: 0.6110 - accuracy: 0.7619 - val_loss: 1.9216 - val_accuracy: 0.3333
# Epoch 80/150
# 1/1 [==============================] - 0s 45ms/step - loss: 0.6335 - accuracy: 0.8095 - val_loss: 1.9308 - val_accuracy: 0.3333
# Epoch 81/150
# 1/1 [==============================] - 0s 46ms/step - loss: 0.5763 - accuracy: 0.8095 - val_loss: 1.8930 - val_accuracy: 0.3333
# Epoch 82/150
# 1/1 [==============================] - 0s 44ms/step - loss: 0.5911 - accuracy: 0.8095 - val_loss: 1.9354 - val_accuracy: 0.3333
# Epoch 83/150
# 1/1 [==============================] - 0s 44ms/step - loss: 0.5533 - accuracy: 0.8095 - val_loss: 1.8986 - val_accuracy: 0.3333
# Epoch 84/150
# 1/1 [==============================] - 0s 48ms/step - loss: 0.5634 - accuracy: 0.8095 - val_loss: 1.9388 - val_accuracy: 0.3333
# Epoch 85/150
# 1/1 [==============================] - 0s 47ms/step - loss: 0.5296 - accuracy: 0.8571 - val_loss: 1.8915 - val_accuracy: 0.3333
# Epoch 86/150
# 1/1 [==============================] - 0s 51ms/step - loss: 0.5336 - accuracy: 0.8095 - val_loss: 1.9472 - val_accuracy: 0.3333
# Epoch 87/150
# 1/1 [==============================] - 0s 50ms/step - loss: 0.5118 - accuracy: 0.8571 - val_loss: 1.8880 - val_accuracy: 0.3333
# Epoch 88/150
# 1/1 [==============================] - 0s 45ms/step - loss: 0.5090 - accuracy: 0.8095 - val_loss: 1.9576 - val_accuracy: 0.3333
# Epoch 89/150
# 1/1 [==============================] - 0s 47ms/step - loss: 0.4987 - accuracy: 0.8571 - val_loss: 1.8836 - val_accuracy: 0.6667
# Epoch 90/150
# 1/1 [==============================] - 0s 46ms/step - loss: 0.4876 - accuracy: 0.8095 - val_loss: 1.9699 - val_accuracy: 0.3333
# Epoch 91/150
# 1/1 [==============================] - 0s 44ms/step - loss: 0.4920 - accuracy: 0.8571 - val_loss: 1.8813 - val_accuracy: 0.6667
# Epoch 92/150
# 1/1 [==============================] - 0s 47ms/step - loss: 0.4716 - accuracy: 0.8095 - val_loss: 1.9816 - val_accuracy: 0.3333
# Epoch 93/150
# 1/1 [==============================] - 0s 45ms/step - loss: 0.4915 - accuracy: 0.8571 - val_loss: 1.8858 - val_accuracy: 0.3333
# Epoch 94/150
# 1/1 [==============================] - 0s 45ms/step - loss: 0.4635 - accuracy: 0.8571 - val_loss: 1.9878 - val_accuracy: 0.3333
# Epoch 95/150
# 1/1 [==============================] - 0s 48ms/step - loss: 0.4951 - accuracy: 0.8571 - val_loss: 1.9045 - val_accuracy: 0.3333
# Epoch 96/150
# 1/1 [==============================] - 0s 46ms/step - loss: 0.4653 - accuracy: 0.9048 - val_loss: 1.9816 - val_accuracy: 0.3333
# Epoch 97/150
# 1/1 [==============================] - 0s 47ms/step - loss: 0.4981 - accuracy: 0.8571 - val_loss: 1.9432 - val_accuracy: 0.3333
# Epoch 98/150
# 1/1 [==============================] - 0s 46ms/step - loss: 0.4741 - accuracy: 0.9048 - val_loss: 1.9596 - val_accuracy: 0.3333
# Epoch 99/150
# 1/1 [==============================] - 0s 50ms/step - loss: 0.4954 - accuracy: 0.8571 - val_loss: 2.0012 - val_accuracy: 0.3333
# Epoch 100/150
# 1/1 [==============================] - 0s 46ms/step - loss: 0.4820 - accuracy: 0.8571 - val_loss: 1.9282 - val_accuracy: 0.3333
# Epoch 101/150
# 1/1 [==============================] - 0s 47ms/step - loss: 0.4869 - accuracy: 0.8571 - val_loss: 2.0665 - val_accuracy: 0.3333
# Epoch 102/150
# 1/1 [==============================] - 0s 44ms/step - loss: 0.4833 - accuracy: 0.8571 - val_loss: 1.9002 - val_accuracy: 0.3333
# Epoch 103/150
# 1/1 [==============================] - 0s 49ms/step - loss: 0.4753 - accuracy: 0.8571 - val_loss: 2.1207 - val_accuracy: 0.3333
# Epoch 104/150
# 1/1 [==============================] - 0s 50ms/step - loss: 0.4772 - accuracy: 0.9048 - val_loss: 1.8847 - val_accuracy: 0.3333
# Epoch 105/150
# 1/1 [==============================] - 0s 52ms/step - loss: 0.4612 - accuracy: 0.8571 - val_loss: 2.1537 - val_accuracy: 0.3333
# Epoch 106/150
# 1/1 [==============================] - 0s 55ms/step - loss: 0.4641 - accuracy: 0.9048 - val_loss: 1.8834 - val_accuracy: 0.3333
# Epoch 107/150
# 1/1 [==============================] - 0s 46ms/step - loss: 0.4444 - accuracy: 0.8571 - val_loss: 2.1701 - val_accuracy: 0.3333
# Epoch 108/150
# 1/1 [==============================] - 0s 57ms/step - loss: 0.4465 - accuracy: 0.9048 - val_loss: 1.8917 - val_accuracy: 0.3333
# Epoch 109/150
# 1/1 [==============================] - 0s 45ms/step - loss: 0.4258 - accuracy: 0.9048 - val_loss: 2.1779 - val_accuracy: 0.3333
# Epoch 110/150
# 1/1 [==============================] - 0s 48ms/step - loss: 0.4275 - accuracy: 0.9048 - val_loss: 1.9046 - val_accuracy: 0.3333
# Epoch 111/150
# 1/1 [==============================] - 0s 49ms/step - loss: 0.4072 - accuracy: 0.9048 - val_loss: 2.1826 - val_accuracy: 0.3333
# Epoch 112/150
# 1/1 [==============================] - 0s 51ms/step - loss: 0.4092 - accuracy: 0.9048 - val_loss: 1.9192 - val_accuracy: 0.3333
# Epoch 113/150
# 1/1 [==============================] - 0s 49ms/step - loss: 0.3895 - accuracy: 0.9048 - val_loss: 2.1864 - val_accuracy: 0.3333
# Epoch 114/150
# 1/1 [==============================] - 0s 50ms/step - loss: 0.3927 - accuracy: 0.9048 - val_loss: 1.9341 - val_accuracy: 0.3333
# Epoch 115/150
# 1/1 [==============================] - 0s 46ms/step - loss: 0.3736 - accuracy: 0.9048 - val_loss: 2.1906 - val_accuracy: 0.3333
# Epoch 116/150
# 1/1 [==============================] - 0s 47ms/step - loss: 0.3785 - accuracy: 0.9048 - val_loss: 1.9485 - val_accuracy: 0.3333
# Epoch 117/150
# 1/1 [==============================] - 0s 52ms/step - loss: 0.3597 - accuracy: 0.9048 - val_loss: 2.1956 - val_accuracy: 0.3333
# Epoch 118/150
# 1/1 [==============================] - 0s 52ms/step - loss: 0.3665 - accuracy: 0.9048 - val_loss: 1.9620 - val_accuracy: 0.3333
# Epoch 119/150
# 1/1 [==============================] - 0s 47ms/step - loss: 0.3478 - accuracy: 0.9048 - val_loss: 2.2017 - val_accuracy: 0.3333
# Epoch 120/150
# 1/1 [==============================] - 0s 46ms/step - loss: 0.3563 - accuracy: 0.9048 - val_loss: 1.9742 - val_accuracy: 0.3333
# Epoch 121/150
# 1/1 [==============================] - 0s 47ms/step - loss: 0.3376 - accuracy: 1.0000 - val_loss: 2.2088 - val_accuracy: 0.3333
# Epoch 122/150
# 1/1 [==============================] - 0s 53ms/step - loss: 0.3476 - accuracy: 0.9048 - val_loss: 1.9849 - val_accuracy: 0.3333
# Epoch 123/150
# 1/1 [==============================] - 0s 51ms/step - loss: 0.3288 - accuracy: 1.0000 - val_loss: 2.2173 - val_accuracy: 0.3333
# Epoch 124/150
# 1/1 [==============================] - 0s 51ms/step - loss: 0.3398 - accuracy: 0.9048 - val_loss: 1.9940 - val_accuracy: 0.3333
# Epoch 125/150
# 1/1 [==============================] - 0s 46ms/step - loss: 0.3212 - accuracy: 1.0000 - val_loss: 2.2269 - val_accuracy: 0.3333
# Epoch 126/150
# 1/1 [==============================] - 0s 46ms/step - loss: 0.3328 - accuracy: 0.9048 - val_loss: 2.0015 - val_accuracy: 0.3333
# Epoch 127/150
# 1/1 [==============================] - 0s 48ms/step - loss: 0.3143 - accuracy: 1.0000 - val_loss: 2.2378 - val_accuracy: 0.3333
# Epoch 128/150
# 1/1 [==============================] - 0s 46ms/step - loss: 0.3263 - accuracy: 0.9048 - val_loss: 2.0076 - val_accuracy: 0.3333
# Epoch 129/150
# 1/1 [==============================] - 0s 47ms/step - loss: 0.3081 - accuracy: 1.0000 - val_loss: 2.2498 - val_accuracy: 0.3333
# Epoch 130/150
# 1/1 [==============================] - 0s 46ms/step - loss: 0.3202 - accuracy: 0.9048 - val_loss: 2.0123 - val_accuracy: 0.3333
# Epoch 131/150
# 1/1 [==============================] - 0s 45ms/step - loss: 0.3024 - accuracy: 1.0000 - val_loss: 2.2627 - val_accuracy: 0.3333
# Epoch 132/150
# 1/1 [==============================] - 0s 54ms/step - loss: 0.3143 - accuracy: 0.9048 - val_loss: 2.0159 - val_accuracy: 0.3333
# Epoch 133/150
# 1/1 [==============================] - 0s 45ms/step - loss: 0.2972 - accuracy: 1.0000 - val_loss: 2.2765 - val_accuracy: 0.3333
# Epoch 134/150
# 1/1 [==============================] - 0s 46ms/step - loss: 0.3088 - accuracy: 0.9048 - val_loss: 2.0185 - val_accuracy: 0.3333
# Epoch 135/150
# 1/1 [==============================] - 0s 45ms/step - loss: 0.2924 - accuracy: 1.0000 - val_loss: 2.2909 - val_accuracy: 0.3333
# Epoch 136/150
# 1/1 [==============================] - 0s 46ms/step - loss: 0.3035 - accuracy: 0.9048 - val_loss: 2.0203 - val_accuracy: 0.3333
# Epoch 137/150
# 1/1 [==============================] - 0s 45ms/step - loss: 0.2881 - accuracy: 1.0000 - val_loss: 2.3057 - val_accuracy: 0.3333
# Epoch 138/150
# 1/1 [==============================] - 0s 46ms/step - loss: 0.2985 - accuracy: 0.9048 - val_loss: 2.0214 - val_accuracy: 0.3333
# Epoch 139/150
# 1/1 [==============================] - 0s 48ms/step - loss: 0.2843 - accuracy: 1.0000 - val_loss: 2.3209 - val_accuracy: 0.3333
# Epoch 140/150
# 1/1 [==============================] - 0s 48ms/step - loss: 0.2937 - accuracy: 0.9524 - val_loss: 2.0220 - val_accuracy: 0.3333
# Epoch 141/150
# 1/1 [==============================] - 0s 48ms/step - loss: 0.2811 - accuracy: 1.0000 - val_loss: 2.3360 - val_accuracy: 0.3333
# Epoch 142/150
# 1/1 [==============================] - 0s 45ms/step - loss: 0.2893 - accuracy: 0.9524 - val_loss: 2.0224 - val_accuracy: 0.3333
# Epoch 143/150
# 1/1 [==============================] - 0s 52ms/step - loss: 0.2784 - accuracy: 1.0000 - val_loss: 2.3510 - val_accuracy: 0.3333
# Epoch 144/150
# 1/1 [==============================] - 0s 47ms/step - loss: 0.2852 - accuracy: 0.9524 - val_loss: 2.0226 - val_accuracy: 0.3333
# Epoch 145/150
# 1/1 [==============================] - 0s 47ms/step - loss: 0.2763 - accuracy: 1.0000 - val_loss: 2.3654 - val_accuracy: 0.3333
# Epoch 146/150
# 1/1 [==============================] - 0s 45ms/step - loss: 0.2814 - accuracy: 0.9524 - val_loss: 2.0230 - val_accuracy: 0.3333
# Epoch 147/150
# 1/1 [==============================] - 0s 45ms/step - loss: 0.2746 - accuracy: 1.0000 - val_loss: 2.3790 - val_accuracy: 0.3333
# Epoch 148/150
# 1/1 [==============================] - 0s 48ms/step - loss: 0.2778 - accuracy: 0.9524 - val_loss: 2.0237 - val_accuracy: 0.3333
# Epoch 149/150
# 1/1 [==============================] - 0s 44ms/step - loss: 0.2733 - accuracy: 1.0000 - val_loss: 2.3913 - val_accuracy: 0.3333
# Epoch 150/150
# 1/1 [==============================] - 0s 47ms/step - loss: 0.2745 - accuracy: 0.9524 - val_loss: 2.0252 - val_accuracy: 0.3333
#
# >Entrenamiento Finalizado.

# %%
#@title Mostrar Gráficos del Entrenamiento
plt.figure(figsize=(15,8)) 
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Gráfico del Error del Entrenamiento')
plt.ylabel('')
plt.xlabel('epoch')
plt.legend(['entrenamiento', 'validación'], loc='upper left')
plt.show()

plt.figure(figsize=(15,8)) 
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Gráfico de la Exactitud del Entrenamiento')
plt.ylabel('')
plt.xlabel('epoch')
plt.legend(['entrenamiento', 'validación'], loc='upper left')
plt.show()

# %%
#@title Probar red entrenada con datos de entrenamiento
mostrar_detalle_imagenes_entrenamiento = False #@param {type:"boolean"}

# función auxiliar para probar el modelo entrenado en detalle
def probarModelo(x, y, esDAimag, clases_map, mostrarImagenes=False):

    # procesa las imágenes de prueba con el modelo 
    predClass = model.predict(x)

    # muestra los resultados con las imágenes 
    umbralClas = 0.5
    classPreds = []
    classReal = []
    for i in range(len(x)):

        # asigna el nombre de la clase real
        clReal = clases_map[ y[i] ] 

        # determina la clase predecida
        if tipo_output_softMax:
            ## determina clase predecida de acuerdo a la que tiene mayor valor
            idclPred = int( np.argmax(predClass[i], axis=0) )
            idclPredRnd = idclPred
        else:
            ## determina clase predecida de acuerdo al umbral de clasificación
            idclPred = predClass[i][0]       
            idclPredRnd = int(idclPred)
            if (idclPred - idclPredRnd)>0.5 and (idclPredRnd+1)<len(clases_map):
                    idclPredRnd = idclPredRnd + 1

        # asigna el nombre de la clase predecida
        if idclPredRnd<0 or idclPredRnd>=len(clases_map):
            clPred = "CLASE " + str(idclPredRnd) + " INVÁLIDA!"
        else:      
            clPred = clases_map[ idclPredRnd ]

        # agrega a vevtores auxiliares
        classReal.append( clReal )
        classPreds.append( clPred )

        # sólo muestra las imágenes no generadas por DA
        if mostrarImagenes:
          strTitulo = 'Real: ' + clReal + ' / RNA: ' 
          strTitulo = strTitulo + clPred + ' (' + str( idclPred ) +')'    

          # muestra comparación con la imagen
          fig = plt.figure()
          fig.suptitle( strTitulo )
          ax1 = fig.add_subplot(121)
          plot_image( x[i] )
          
          plt.tight_layout()
          fig = plt.gcf()

    # muestra reporte de clasificación
    print("\n Reporte de Clasificación: ")
    print(classification_report(classReal, classPreds))

    # muestra matriz de confusion
    print('\nMatriz de Confusión: ')
    cm = confusion_matrix(classReal, classPreds, labels=clases_map)
    cmtx = pd.DataFrame(
        cm, 
        index=['r:{:}'.format(x) for x in clases_map], 
        columns=['p:{:}'.format(x) for x in clases_map]
      )
    print(cmtx)
    print("\n")

    if mostrarImagenes:
      print("\n>Resultados: ")


# prueba con los datos de prueba
print("*** Resultados con datos de Entrenamiento: ")
probarModelo(x_train, y_train, esDAimag_train, clases_map, mostrar_detalle_imagenes_entrenamiento)
# Out:
# *** Resultados con datos de Entrenamiento:
#
#  Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#        alfil       1.00      0.75      0.86         4
#      caballo       1.00      0.75      0.86         4
#         peon       1.00      1.00      1.00         4
#        reina       1.00      1.00      1.00         4
#          rey       0.80      1.00      0.89         4
#        torre       0.80      1.00      0.89         4
#
#     accuracy                           0.92        24
#    macro avg       0.93      0.92      0.92        24
# weighted avg       0.93      0.92      0.92        24
#
#
# Matriz de Confusión:
#            p:reina  p:peon  p:caballo  p:rey  p:torre  p:alfil
# r:reina          4       0          0      0        0        0
# r:peon           0       4          0      0        0        0
# r:caballo        0       0          3      0        1        0
# r:rey            0       0          0      4        0        0
# r:torre          0       0          0      0        4        0
# r:alfil          0       0          0      1        0        3

# %% [markdown]
# 7) Evaluar el modelo de la RNA entrenado usando las imágenes de prueba:

# %%
#@title Probar red entrenada con datos de prueba
mostrar_detalle_imagenes_prueba = False #@param {type:"boolean"}
 
 # evalua al modelo entrenado
resEval = model.evaluate(x_test, (y_testEnc if tipo_output_softMax else y_test),)
print("\n>Evaluación del Modelo: ")
print("    - Error: ", resEval[0])
print("    - Exactitud: ", resEval[1]*100)
print("\n")

# prueba con los datos de entrenamiento
print("\n\n*** Resultados con datos de Prueba: ")
probarModelo(x_test, y_test, esDAimag_test, clases_map, mostrar_detalle_imagenes_prueba)
# Out:
# 1/1 [==============================] - 0s 30ms/step - loss: 2.4777 - accuracy: 0.2222
#
# >Evaluación del Modelo:
#     - Error:  2.477677345275879
#     - Exactitud:  22.22222238779068
#
#
#
#
# *** Resultados con datos de Prueba:
#
#  Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#        alfil       0.00      0.00      0.00         3
#      caballo       0.00      0.00      0.00         3
#         peon       0.00      0.00      0.00         3
#        reina       0.25      0.67      0.36         3
#          rey       0.00      0.00      0.00         3
#        torre       0.29      0.67      0.40         3
#
#     accuracy                           0.22        18
#    macro avg       0.09      0.22      0.13        18
# weighted avg       0.09      0.22      0.13        18
#
#
# Matriz de Confusión:
#            p:reina  p:peon  p:caballo  p:rey  p:torre  p:alfil
# r:reina          2       0          0      0        1        0
# r:peon           1       0          0      0        2        0
# r:caballo        2       0          0      0        1        0
# r:rey            1       0          0      0        0        2
# r:torre          1       0          0      0        2        0
# r:alfil          1       1          0      0        1        0
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
